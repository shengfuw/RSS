# %%
import csv
import random
import numpy as np
import multiprocessing
import matplotlib.pyplot as plt
from model_20 import one_trial

random.seed(20) 
np.random.seed(20)

n_cpus = multiprocessing.cpu_count()
manager = multiprocessing.Manager()
log_data = manager.list()

trial_num = 1
args = []
for netsize in [500, 1500, 2000, 2500, 3000, 5000]:
    args.append((netsize, log_data))
args = args * trial_num

print("cpu count: {}".format(n_cpus))
pool = multiprocessing.Pool(n_cpus+2)
pool.starmap(one_trial, args)

# %%
# save log data to csv
data_file_path = 'data.csv'
with open(data_file_path, 'w', newline='') as output_file:
    writer = csv.writer(output_file)
    for data in log_data:   
        writer.writerow(data)

# %%
import pandas as pd

columns = ['Netsize', 'Corr of Opinion', 'Energy', 'IsEquil', 'Iteration number', 'Time']
df = pd.read_csv('data.csv', header=None, names=columns)

df
# Out:
#    Netsize  Corr of Opinion    Energy  IsEquil  Iteration number  \
# 0      500         1.000000 -1.998380     True           1530001
# 1     1500         0.989494 -1.990670     True           5700001
# 2     2000         0.989500 -1.985700     True          10650001
# 3     2500         0.968439 -1.994083     True          15030001
# 4     3000         1.000000 -1.986772     True          31030001
# 5     5000         0.013582 -0.080258    False         100000000
#
#               Time
# 0          1:13:34
# 1          5:16:02
# 2         10:33:55
# 3         15:29:15
# 4   1 day, 9:07:59
# 5  5 days, 7:43:11
